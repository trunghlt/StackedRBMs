# %%
sparsity_accuracy = [
    (.001, .65),
    (.002, .66),
    (.003, .62),
    (.004, .67),
    (.005, .68),
    (.006, .71),
    (.007, .71),
    (.008, .73),
    (.009, .75),
    (.010, .74),
    (.011, .74),
    (.012, .73),
    (.013, .73),
    (.014, .73),
    (.015, .72),
    (.016, .73),
    (.017, .71),
    (.018, .71),
    (.019, .72),
    (.020, .70)
]

# %%
f = figure(figsize=(10, 6))
x, y = zip(*sparsity_accuracy)
params_1d = polyfit(x, y, 3)
scatter(x, y, label="Experimental results")
plot(x, poly1d(params_1d)(x), label="Fitted LSR")
xlabel("Sparsity of $1^{st}$ hidden layer")
ylabel("Accuracy")
title("Subjectivity/Objectivity classification with Google Embeddings")
legend()

# %%
f.savefig("Google_embeddings_accuracy.pdf")
